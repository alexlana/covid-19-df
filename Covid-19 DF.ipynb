# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('data.tsv', sep='\t')

# %%
df
# Out:
#      date  total_infected  delta_infected  total_deaths  delta_deaths  \
# 0   27/02               1               1             0             0
# 1   28/02               1               0             0             0
# 2   29/02               1               0             0             0
# 3   01/03               2               1             0             0
# 4   02/03               3               1             0             0
# ..    ...             ...             ...           ...           ...
# 62  29/04            1585              94            30             1
# 63  30/04            1672              87            31             1
# 64  01/05            1691              19            32             1
# 65  02/05            1716              25            33             1
# 66  03/05            1720               4            33             0
#
#     recovered
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ..        ...
# 62          0
# 63          0
# 64          0
# 65          0
# 66          0
#
# [67 rows x 6 columns]

# %%
plt.figure(figsize=(16, 6))
plt.xticks(rotation=70)
plt.tight_layout()

sns.set(style="whitegrid")
ax = sns.barplot(x="date", y="total_infected", data=df,  color="blue", saturation=.5)

# %%
plt.figure(figsize=(16, 6))
plt.xticks(rotation=70)
plt.tight_layout()

ax = sns.lineplot(x="date", y="total_infected", data=df, sort=False)

# %%
plt.figure(figsize=(16, 6))
plt.xticks(rotation=70)
plt.tight_layout()

ax = sns.lineplot(x="date", y="total_infected", data=df, sort=False)
ax.set_yscale('log')
